# %% [markdown]
# <a href="https://colab.research.google.com/github/michaeldavis42/examen/blob/main/bryan_kurt_004d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
entradas = {
    "1A": True,
    "1B": True,
    "1C": True,
    #...
    "10C": True
}

entradas = {...} # entradas disponibles/vendidas

while True:
    # mostrar menú
    print("Bienvenido al sistema de ventas de entradas")
    print("1. Comprar entradas")
    print("2. Mostrar ubicaciones disponibles")
    print("3. Ver listado de asistentes")
    print("4. Mostrar ganancias totales")
    print("5. Salir")

    opcion = input("Seleccione una de las opción: ")

    if opcion == "1":
        # comprar entradas
        pass
    elif opcion == "2":
        # mostrar ubicaciones disponibles
        pass
    elif opcion == "3":
        # ver listado de asistentes
        pass
    elif opcion == "4":
        # mostrar ganancias totales
        pass
    elif opcion == "5":
        # salir del programa
        break
    else:
        # opción inválida
        print("Opción inválida, intente nuevamente")

if opcion == "1":
    # comprar entradas
    cantidad = int(input("Cantidad de entradas a comprar (máximo 3): "))
    if cantidad < 1 or cantidad > 3:
        print("Cantidad inválida")
    else:
        disponibles = [key for key, value in entradas.items() if value]
        if len(disponibles) < cantidad:
            print("No hay suficientes entradas disponibles")
        else:
            print("Entradas disponibles:")
            for i, entrada in enumerate(disponibles):
                print(f"{i+1}. {entrada}")
            seleccionadas = []
            for i in range(cantidad):
                indice = int(input(f"Seleccione entrada {i+1}: "))
                if indice < 1 or indice > len(disponibles):
                    print("Índice inválido")
                    break
                else:
                    seleccionadas.append(disponibles[indice-1])
            else:
                # todas las entradas seleccionadas son válidas
                for entrada in seleccionadas:
                    entradas[entrada] = False
                print("Entradas compradas con éxito")




elif opcion == "2":
    # mostrar ubicaciones disponibles
    disponibles = [key for key, value in entradas.items() if value]
    print("Entradas disponibles:")
    for entrada in disponibles:
        print(entrada)


elif opcion == "3":
    # ver listado de asistentes
    vendidas = [key for key, value in entradas.items() if not value]
    print("Listado de asistentes:")
    for entrada in vendidas:
        print(entrada)

elif opcion == "4":
    # mostrar ganancias totales
    precio_entrada = 1000 # ejemplo
    vendidas = [key for key, value in entradas.items() if not value]
    ganancias = len(vendidas) * precio_entrada
    print(f"Ganancias totales: ${ganancias}")

entradas = {
    "1A": True,
    "1B": True,
    "1C": True,
    "2A": True,
    "2B": True,
    "2C": True,
    "3A": True,
    "3B": True,
    "3C": True,
    "4A": True,
    "4B": True,
    "4C": True,
    "5A": True,
    "5B": True,
    "5C": True,
    "6A": True,
    "6B": True,
    "6C": True,
    "7A": True,
    "7B": True,
    "7C": True,
    "8A": True,
    "8B": True,
    "8C": True,
    "9A": True,
    "9B": True,
    "9C": True,
    "10A": True,
    "10B": True,
    "10C": True
}

while True:
    # mostrar menú
    print("Bienvenido al sistema de venta de entradas")
    print("1. Comprar entradas")
    print("2. Mostrar ubicaciones disponibles")
    print("3. Ver listado de asistentes")
    print("4. Mostrar ganancias totales")
    print("5. Salir")

    opcion = input("Seleccione una opción: ")

    if opcion == "1":
        # comprar entradas
        cantidad = int(input("Cantidad de entradas a comprar (máximo 3): "))
        if cantidad < 1 or cantidad > 3:
            print("Cantidad inválida")
        else:
            disponibles = [key for key, value in entradas.items() if value]
            if len(disponibles) < cantidad:
                print("No hay suficientes entradas disponibles")
            else:
                print("Entradas disponibles:")
                for i, entrada in enumerate(disponibles):
                    print(f"{i+1}. {entrada}")
                seleccionadas = []
                for i in range(cantidad):
                    indice = int(input(f"Seleccione entrada {i+1}: "))
                    if indice < 1 or indice > len(disponibles):
                        print("Índice inválido")
                        break
                    else:
                        seleccionadas.append(disponibles[indice-1])
                else:
                    # todas las entradas seleccionadas son válidas
                    for entrada in seleccionadas:
                        entradas[entrada] = False
                    print("Entradas compradas con éxito")
    elif opcion == "2":
        # mostrar ubicaciones disponibles
        disponibles = [key for key, value in entradas.items() if value]
        print("Entradas disponibles:")
        for entrada in disponibles:
            print(entrada)
    elif opcion == "3":
        # ver listado de asistentes
        vendidas = [key for key, value in entradas.items() if not value]
        print("Listado de asistentes:")
        for entrada in vendidas:
            print(entrada)
    elif opcion == "4":
        # mostrar ganancias totales
        precio_entrada = 1000 # ejemplo
        vendidas = [key for key, value in entradas.items() if not value]
        ganancias = len(vendidas) * precio_entrada
        print(f"Ganancias totales: ${ganancias}")
    elif opcion == "5":
        # salir del programa
        break
    else:
        # opción inválida
        print("Opción inválida, intente nuevamente")



def mostrar_ubicaciones(ubicaciones):
    for i, ubicacion in enumerate(ubicaciones):
        estado = 'Vendida' if ubicacion['vendida'] else 'Disponible'
        print(f"{i+1}. {ubicacion['nombre']} - {estado}")

def comprar_entradas(ubicaciones):
    cantidad_entradas = input("Ingrese la cantidad de entradas a comprar (entre 1 y 3): ")
    while not cantidad_entradas.isdigit() or int(cantidad_entradas) < 1 or int(cantidad_entradas) > 3:
        cantidad_entradas = input("Cantidad inválida. Ingrese la cantidad de entradas a comprar (entre 1 y 3): ")

    cantidad_entradas = int(cantidad_entradas)

    ubicaciones_disponibles = [ubicacion for ubicacion in ubicaciones if not ubicacion['vendida']]

    print("Ubicaciones disponibles:")
    mostrar_ubicaciones(ubicaciones_disponibles)

    entradas_compradas = []
    for _ in range(cantidad_entradas):
        ubicacion_seleccionada = input("Seleccione una ubicación: ")

        while not ubicacion_seleccionada.isdigit() or int(ubicacion_seleccionada) < 1 or int(ubicacion_seleccionada) > len(ubicaciones_disponibles):
            ubicacion_seleccionada = input("Ubicación inválida. Seleccione una ubicación: ")

        ubicacion_seleccionada = int(ubicacion_seleccionada) - 1

        if ubicaciones_disponibles[ubicacion_seleccionada]['vendida']:
            print("Ubicación no disponible. Seleccione otra.")
        else:
            entradas_compradas.append(ubicaciones_disponibles[ubicacion_seleccionada])
            ubicaciones_disponibles[ubicacion_seleccionada]['vendida'] = True

    return entradas_compradas

def mostrar_listado_asistentes(entradas_compradas):
    print("Listado de asistentes:")
    for i, entrada in enumerate(entradas_compradas):
        print(f"{i+1}. {entrada['nombre']} - {entrada['ubicacion']}")

def mostrar_ganancias_totales(entradas_compradas):
    total = sum(entrada['precio'] for entrada in entradas_compradas)
    print("Ganancias totales:", total)

def main():
    ubicaciones = [
        {'nombre': 'Platinum', 'vendida': False, 'precio': 120000},
        {'nombre': 'Gold', 'vendida': False, 'precio': 80000},
        {'nombre': 'Silver', 'vendida': False, 'precio': 50000}
    ]

    while True:
        print("Menú:")
        print("1. Comprar entradas")
        print("2. Mostrar ubicaciones disponibles")
        print("3. Ver listado de asistentes")
        print("4. Mostrar ganancias totales")
        print("5. Salir")

        opcion = input("Seleccione una opción: ")
        while not opcion.isdigit() or int(opcion) < 1 or int(opcion) > 5:
            opcion = input("Opción inválida. Seleccione una opción: ")

        opcion = int(opcion)

        if opcion == 1:
            entradas_compradas = comprar_entradas(ubicaciones)
            print("Entradas compradas exitosamente.")
            mostrar_listado_asistentes(entradas_compradas)
        elif opcion == 2:
            print("Ubicaciones:")
            mostrar_ubicaciones(ubicaciones)
        elif opcion == 3:
            if any(ubicacion['vendida'] for ubicacion in ubicaciones):
                mostrar_listado_asistentes([ubicacion for ubicacion in ubicaciones if ubicacion['vendida']])
            else:
                print("No existen asistentes aún.")
        elif opcion == 4:
            if any(ubicacion['vendida'] for ubicacion in ubicaciones):
                mostrar_ganancias_totales([ubicacion for ubicacion in ubicaciones if ubicacion['vendida']])
            else:
                print("No existen ganancias aún.")
        elif opcion == 5:
            break
# Out:
# Bienvenido al sistema de ventas de entradas
# 1. Comprar entradas
# 2. Mostrar ubicaciones disponibles
# 3. Ver listado de asistentes
# 4. Mostrar ganancias totales
# 5. Salir
